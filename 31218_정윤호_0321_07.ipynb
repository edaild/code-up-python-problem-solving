# %% [markdown]
# 31218_정윤호_0321_7

# %% [markdown]
# # 6010
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a = int(input())

print(a)
# Out:
# 15
# 15

# %% [markdown]
# # 6011
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
a = float(input())

print(a)
# Out:
# 1.414213
# 1.414213

# %% [markdown]
# # 6012
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a = input()
b = input()

print(a)
print(b)
# Out:
# 1
# 2
# 1
# 2

# %% [markdown]
# # 6013
# ![image.png](attachment:image.png)

# %%
a = input()
b = input()

print(b)
print(a)
# Out:
# ab
# a
# a
# ab
